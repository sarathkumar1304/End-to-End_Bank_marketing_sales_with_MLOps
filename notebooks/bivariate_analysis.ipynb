# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from analysis_src.bivariate_analysis import BivariateAnalysis

# %%
df = pd.read_csv("/home/sarath_kumar/Bank_Marketing/data/bank_marketing.csv")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married        NaN      no     1506     yes   no
# 4   33           NaN   single        NaN      no        1      no   no
#
#   contact  day_of_week month  duration  campaign  pdays  previous poutcome   y
# 0     NaN            5   may       261         1     -1         0      NaN  no
# 1     NaN            5   may       151         1     -1         0      NaN  no
# 2     NaN            5   may        76         1     -1         0      NaN  no
# 3     NaN            5   may        92         1     -1         0      NaN  no
# 4     NaN            5   may       198         1     -1         0      NaN  no

# %%
df['job'] = df['job'].fillna(df['job'].mode()[0])
df['education'] = df['education'].fillna(df['education'].mode()[0])
df['contact'] = df['contact'].fillna(df['contact'].mode()[0])

# %%
df.drop('poutcome',axis=1,inplace = True)

# %%
analysis = BivariateAnalysis(df)

# %%
analysis.bar_plot(x='job',y='balance',hue='y')

# %% [markdown]
# ## Insights:
#
# - **job-Specification Balance** : The plot reveals that the average balance varies significantly across different job categories. For instance, "management" and "retaired" individuals seem to have higher average balances compared to "blue-collar" or "unemployed" individuals
# - **Group Difference** : The plot also suggests that the average balance might differ between the "yes" and "no" groups within each job category. However , without specific values or statistical tests, its difficult to determine the statsitical significance of these differences.

# %%
analysis.bar_plot(x='job',y='duration',hue='y')

# %% [markdown]
# ## Insights:
#
# - **Job- Specific Duration** : The lot reveals that the average duration of interactions varies significantly across different categories. for instance, "management" and "retired" individuals seem to have higher average durations compared to "blue-collar" or "unemployed" individuals
#
# - **Group Differnece** : The plot suggest that the average duration might differ between the "yes" and "no" groups within each job category.
#
# ## Potentional Implications:
#
# - **Markeating Strategy** : The plot could inform the duration of markating interactions. For example, the bank might allocate more time for interaction with individuals in job categories with higher average durations.
#
# - **Customer Satisfaction** : The duration of interactions could be a proxy for customer statification. Higher durations might indicate more in depth dicussion and personalized service.
#
# - **Sales Conversion**: The plot mights suggest a realtionship between interaction duration and campiagn sucess. Longer interaction might lead to higher coversion rates.

# %%
analysis.bar_plot(x='job',y='age',hue='y')

# %% [markdown]
# ## Insights:
# - **Job- Specific Age** : The plot reveals that the average age varies significantly across different job categories.For instance,"retired" individuals have a sigificantly higher avrage age compared to "student" or "unemployed"
#
# - **Group Difference** : The plot also suggests that the avearge age might differ between the "yes" and "no" groups within the each category.

# %%
analysis.box_plot(x='job',y='age')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/bivariate_analysis.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.df, x=x, y=y, palette='Set3')

# %%
analysis.box_plot(x='job',y='duration')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/bivariate_analysis.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.df, x=x, y=y, palette='Set3')

# %%
analysis.box_plot(x='job',y='balance')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/bivariate_analysis.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.df, x=x, y=y, palette='Set3')

# %%
analysis.heatmap()

# %%
analysis.scatter_plot(x='age',y='balance',hue='y')

# %%
analysis.scatter_plot(x='age',y='duration',hue='y')

# %%
analysis.scatter_plot(x='duration',y='balance',hue='y')

# %%
analysis.violin_plot(x='job',y='age')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/bivariate_analysis.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=self.df, x=x, y=y, palette='muted')

# %%
analysis.violin_plot(x='job',y='balance')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/bivariate_analysis.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=self.df, x=x, y=y, palette='muted')

# %%
analysis.violin_plot(x='job',y='duration')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/bivariate_analysis.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=self.df, x=x, y=y, palette='muted')
