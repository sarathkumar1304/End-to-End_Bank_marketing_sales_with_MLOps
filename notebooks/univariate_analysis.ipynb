# %%
import pandas as pd
from analysis_src.univariate_analysis import UnivariateAnalysis

# %%
df = pd.read_csv("/home/sarath_kumar/Bank_Marketing/data/bank_marketing.csv")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married        NaN      no     1506     yes   no
# 4   33           NaN   single        NaN      no        1      no   no
#
#   contact  day_of_week month  duration  campaign  pdays  previous poutcome   y
# 0     NaN            5   may       261         1     -1         0      NaN  no
# 1     NaN            5   may       151         1     -1         0      NaN  no
# 2     NaN            5   may        76         1     -1         0      NaN  no
# 3     NaN            5   may        92         1     -1         0      NaN  no
# 4     NaN            5   may       198         1     -1         0      NaN  no

# %%
df['job'] = df['job'].fillna(df['job'].mode()[0])
df['education'] = df['education'].fillna(df['education'].mode()[0])
df['contact'] = df['contact'].fillna(df['contact'].mode()[0])
df.drop('poutcome',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          45211 non-null  int64
#  1   job          45211 non-null  object
#  2   marital      45211 non-null  object
#  3   education    45211 non-null  object
#  4   default      45211 non-null  object
#  5   balance      45211 non-null  int64
#  6   housing      45211 non-null  object
#  7   loan         45211 non-null  object
#  8   contact      45211 non-null  object
#  9   day_of_week  45211 non-null  int64
#  10  month        45211 non-null  object
#  11  duration     45211 non-null  int64
#  12  campaign     45211 non-null  int64
#  13  pdays        45211 non-null  int64
#  14  previous     45211 non-null  int64
#  15  y            45211 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 5.5+ MB

# %%
analysis = UnivariateAnalysis()

# %%
analysis.NumericalAnalysis(df, 'age')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df[column], palette="muted")
# Summary statistics for age:
# count    45211.000000
# mean        40.936210
# std         10.618762
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %% [markdown]
# ## Insights
# ### Age
# - **Central Tendency** : The highest frequency is around the age range if 30 - 60. This indicates that most indivuals in the dataset are in thus age group
# - **Skewness**: The distribution is slightly **right skewed** since there are fewer older individuals (ages 60 above).
# - **Outliers**: Very few indivuals are above 80 years, suggesting potential outliers.

# %%
analysis.NumericalAnalysis(df, 'balance',sqr=True)
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df[column], palette="muted")
# /home/sarath_kumar/Bank_Marketing/myenv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Summary statistics for balance:
# count     45211.000000
# mean       1362.272058
# std        3044.765829
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: balance, dtype: float64

# %% [markdown]
# ## Insights:
# ### Balance
#
# - **Concentration**:  The majority of the values fall within the lower range of (0-50 on the square root of the features), indicating that most original values values in the column were relatively small.
#
# - **Right Skewness** : Despite the transformation, the data still exhibits slight skewness, meanining there are a few larager values
#
# ## Outliers:
# - The extended tail on the right suggesets the presence of outliers. These outliers represents rows with unusally high balances in the column.
#
#  -  Anomalies in the data
#  -  A seperate population with significantly higher values

# %%
analysis.NumericalAnalysis(df,'duration',sqr=True)
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df[column], palette="muted")
# Summary statistics for duration:
# count    45211.000000
# mean       258.163080
# std        257.527812
# min          0.000000
# 25%        103.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: duration, dtype: float64

# %% [markdown]
# ## Insights
#
# ### Duration:
#
# - In the normal features , most of values fall in the range of 0 to 500 and fewer are above 500 and it is **Right skewness** in distribution.
# - By Transforming the data by square root of features , most of the values fall in between the ~5 to ~20 and it is slightly exhibit  **normal distribution** and have fewer outliers.

# %%
analysis.NumericalAnalysis(df,'campaign',sqr=True)
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df[column], palette="muted")
# Summary statistics for campaign:
# count    45211.000000
# mean         2.763841
# std          3.098021
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         63.000000
# Name: campaign, dtype: float64

# %% [markdown]
# ## Insights:
#
# - **skewness** : The distribution is **right-skewed**, indicating that most **campaign** values are low, even  after the square root transformation.
#
# - **Concentartion** : A significant portion of the data lies between 1 and 2 on the square root scale, meaning most campiagn had only 1-4 calls
#
# - **Outliers** The long tail suggests the presence of some campiagns with significantly higher calls , which may need further analysis.
# - **Impact**: The transformation has reduced the skewness but hasn't completely normalized the data.

# %%
analysis.NumericalAnalysis(df,'pdays',log=True,sqr=True)
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df[column], palette="muted")
# /home/sarath_kumar/Bank_Marketing/myenv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/sarath_kumar/Bank_Marketing/myenv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Summary statistics for pdays:
# count    45211.000000
# mean        40.197828
# std        100.128746
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        871.000000
# Name: pdays, dtype: float64

# %%
analysis.NumericalAnalysis(df,'pdays',log=True)
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df[column], palette="muted")
# /home/sarath_kumar/Bank_Marketing/myenv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Summary statistics for pdays:
# count    45211.000000
# mean        40.197828
# std        100.128746
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        871.000000
# Name: pdays, dtype: float64

# %% [markdown]
# ## Categorical Analysis

# %%
analysis.CategoricalAnalysis(df,'marital')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette="pastel")

# %% [markdown]
# ## Insights:
# ## Marital
#
# - **Married (60.2%)**: The majority of the individuals in the dataset are married, representing a domianant group.
#
# - **Single (28.3%)** : A siginificant portion of individuals is single, accounting for over a quarter of the total.
#
# - **Divorced (11.5)** : A smaller group consists of divorced individuals.
#
# This distribution indicates that marital status mights play a role in the dataset's analysis, with married individuals forming the largest demographic. Further analysis could how marital status impacts other variables , such a  campaign response rates

# %%
analysis.CategoricalAnalysis(df,'job')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette="pastel")

# %% [markdown]
# ## Job Distribution:
#
# - **Blue-collar**: This is the most dominant category , accounting for 22.2% of the total . This suggest a significant portion of the population is employed in manual labor or trades.
#
# - **Management**: The second largest category at 20.9% indicating a substantial managerial workforce.
#
# - **Technician**: Following closely at 16.8% , this category highlights the imporatance of technical skills in the workforce.
#
# - **Admin** : At 11.4% , adminstartive roles constitute a considerable portion of the workforce.
#
# - **service**: With 9.2% , the service sector plays a noticable role in eth employment landscape.
#
# - **Self-Employed** : 5.0% of the population is self-employed, indicating enterpreneural activity.
#
# - **Retaired** : Representing 3.5% of the population, this categoryt highlights the presence of retries i the dataset.

# %%
analysis.CategoricalAnalysis(df,"contact")
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette="pastel")

# %% [markdown]
# ## Contact Distribution:
#
# - Most of the individuals uses cellualar rather than telephone in the dataset.

# %%
analysis.CategoricalAnalysis(df,'education')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette="pastel")

# %% [markdown]
# ## Distribution of Education
#
# - **Dominance of Secondary Education**: The most prominent category is **Secondary education** , comprising  a substabtial 55.4% of the total. This suggest that a significant portion of th population has completed secondary education.
# - **Teritary Education** : The next largest category  is **Teritary** education , accounting 29.4%. This indicates a considerable number of individuals have pursued higher education beyond secondary school.
#
# - **Primary Education** : The smallest category is "Primary education", reprsenting 15.2% o fthe total. This suggest that a portion of the population may have completed primary education but not progressed further.

# %%
analysis.CategoricalAnalysis(df,'default')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette="pastel")

# %% [markdown]
# ## Distribution of Default:
# The majority of individuals in the dataset have no credit default.

# %%
analysis.CategoricalAnalysis(df,'housing')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette="pastel")

# %% [markdown]
# ## Distribution of Housing
#
# - 55.6% Individuals in the dataset have own house and  remaining individuals have no house.

# %%
analysis.CategoricalAnalysis(df,'loan')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette="pastel")

# %% [markdown]
# ## Distribution of the Loan Status
#
# - 84% of the indivuals have no loan previoulsy , and remaining people have loan in progress

# %%
analysis.CategoricalAnalysis(df,'month')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette="pastel")

# %% [markdown]
# ### Distribution of the Month (last contact month of year)
#
# - Most of contact in the month of May (30.4%) and remaining have small portion

# %%
analysis.CategoricalAnalysis(df,'y')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], palette="pastel")

# %% [markdown]
# ## Distribution of **y** (Dependent variable or output):
# has the client subscribed a term deposit?
#
# - Most of the data have not subscribed the term deposit and small portion of data have subscribed
# - The dataset is highly imbalanced. we need to balance the dataset using SMOTE techique

# %%
analysis.box_plot(df,'age')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:108: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[column], palette="Set1")

# %% [markdown]
# ## Insights from Boxplot of Age
# - **Distribution** : The boxplot suggests a right0skewed distribution of the data. The right whisker is longer than the left whisker, indicating that there are move data points on the right side of the box
#
# - **Median** : The median value appears to be around 40 .This means that half of the data points fall below the 40 , and half fall the above.
#
# - **IQR** : The IQR , represented by the height of the box, seems to be relatively small. This suggests that the middle 50% of the data points are clustered together within a narrow range.
#
# - **outliers** : There are several data points beyond the right whisker,indicating the presence of potential outliers.These outliers might be individuals with significantly higher ages compared to majority of the data.

# %%
analysis.box_plot(df,'duration')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:108: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[column], palette="Set1")

# %% [markdown]
# ## Insights from the boxplot of Duration.
#
# The minimum duration is 0 and maximum duration is ~900 and remaining datapoints are considered as outliers

# %%
analysis.box_plot(df,'balance')
# Out:
# /home/sarath_kumar/Bank_Marketing/notebooks/analysis_src/univariate_analysis.py:108: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[column], palette="Set1")
